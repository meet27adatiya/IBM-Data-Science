# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Data Science Demo

# %% [markdown]
# Introduction : This notebook tends to show the basic uses of the jupyter notebook and some functionalities that it provides.

# %% [markdown]
# Data Science Languages that are used popularly are :-
# 1)Python
# 2)R
# 3)Tableau
# 4)Julia
# 5)Scala

# %% [markdown]
# Data Science libraries are:-
# 1)scikit learn
# 2)matplotlib
# 3)numpy
# 4)pandas
# 5)seaborn

# %% [markdown]
# Data Science tools available are:
# | Data Science tools |
# | ---------          |
# | SQL                |
# | Tableau            |
# | Python             |
# | Apache Spark       |
# | Tensor Board       |
# | Docker             |

# %% [markdown]
# # Arithmetic Expressions Examples
#
# Arithmetic expressions involve mathematical operations such as addition, subtraction, multiplication, and division. In this section, we'll explore some basic arithmetic expressions using numbers.
#
# ## Addition
#
# The addition operator (`+`) is used to add two numbers. For example:
#
# ```python
# 2 + 3   # Result: 5

# %% [markdown]
# ## Subtraction
#
# The minus operator (`-`) is used to subtract two numbers. For example:
#
# ```python

# %% [markdown]
# 7 - 4   # Result: 3

# %% [markdown]
# # Multiply and Add Numbers
#
# # Define two numbers
# num1 = 5
# num2 = 3
#
# # Perform multiplication
# result_multiply = num1 * num2
#
# # Perform addition
# result_add = num1 + num2
#
# # Display the results
# result_multiply, result_add

# %% [markdown]
# # Convert Minutes to Hours
#
# # Define the number of minutes
# minutes = 120
#
# # Convert minutes to hours
# hours = minutes / 60
#
# # Display the result
# hours

# %% [markdown]
# # Objectives
#
# In this section, we outline the objectives of our analysis or code implementation. Clearly defining objectives helps to provide focus and direction to the work being done. Here are the key objectives for this project:
#
# 1. **Data Exploration:**
#    - Gain a comprehensive understanding of the dataset.
#    - Identify key features and their distributions.
#
# 2. **Data Cleaning:**
#    - Handle missing values, outliers, or any data inconsistencies.
#    - Ensure the dataset is ready for analysis.
#
# 3. **Analysis and Visualization:**
#    - Conduct exploratory data analysis (EDA) to uncover patterns and insights.
#    - Visualize relevant trends and relationships in the data.
#
# 4. **Model Building (if applicable):**
#    - Define the problem statement and the type of model to be built.
#    - Split the data into training and testing sets.
#    - Build, train, and evaluate machine learning models.
#
# 5. **Results Interpretation:**
#    - Interpret the results obtained from analysis or modeling.
#    - Clearly communicate findings and insights.
#
# 6. **Documentation:**
#    - Document the code, methods, and key decisions made during the analysis.
#    - Provide clear explanations for the results obtained.
#
# 7. **Presentation:**
#    - Prepare a summary or presentation of the key findings.
#    - Communicate the results effectively to stakeholders.
#
# 8. **Iterative Refinement (if needed):**
#    - Review and refine the analysis or model based on feedback.
#    - Iterate on the process for continuous improvement.

# %% [markdown]
# The author of this notebook is :- Meet Adatiya
